# %%
import seaborn as sns
import pandas as pd

# %%
novor_df = pd.read_csv('/Users/lukas/University/Bachelor_Thesis/Project/PeptideDeNovoSequencing/Data/Result/Analysis_DeepNovo_Result.tsv', sep='\t', index_col=0)
print(novor_df.head())
# Out:
#         Peptide    Sequence  Similarity  Identity
# 0  AAGAEDEAGAAR  VAMAMGSHPR    0.384615  0.250000
# 1    AAEYTGSSFR  VAMAMGSHPR    0.333333  0.400000
# 2    HDEATSAMVK  VAMAMGSHPR    0.307692  0.100000
# 3   AVFTGSSGYAE  VAMAMGSHPR    0.416667  0.090909
# 4     FAYACGFPR  VAMAMGSHPR    0.500000  0.500000

# %%
similarity_pt = sns.histplot(novor_df['Similarity'], bins=100)
similarity_pt.set_title('Similarity Distribution')
print(novor_df['Similarity'].describe())
print('accuracy', (novor_df.query('Similarity == 1.0').shape[0]))
# Out:
# /Users/lukas/opt/anaconda3/envs/bachelors_thesis/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# count    27960.000000
# mean         0.760427
# std          0.251649
# min          0.000000
# 25%          0.538462
# 50%          0.823529
# 75%          1.000000
# max          1.000000
# Name: Similarity, dtype: float64
# accuracy 11728

# %%
identity_plt=sns.histplot(novor_df['Identity'], bins=100, color='red')
identity_plt.set_title('Identity Distribution')
# Out:
# /Users/lukas/opt/anaconda3/envs/bachelors_thesis/lib/python3.9/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# Text(0.5, 1.0, 'Identity Distribution')
