# %%
import pandas as pd
from matplotlib import pyplot as plt

from scipy.stats import ks_2samp
import numpy as np

# %%
pools = ['Pool_49', 'Pool_52', 'Pool_60']

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
ax0, ax1 = ax
for pool in pools:
        # Load the data
        raw_data =pd.read_csv(
                f"../../Data/Datasets/{pool}/Thermo_SRM_{pool}_01_01_3xHCD-1h-R2-tryptic/msmsScans.txt",
                sep='\t', index_col=None)
        ax0.hist(raw_data['m/z'], bins=100, alpha=0.3, label=' '.join(pool.split('_')))
        if pool != 'Pool_60':
                ax1.hist(raw_data['m/z'], bins=100, alpha=0.3, label=' '.join(pool.split('_')))

ax0.set_title('Histogram of Mass values for all pools')
ax0.set_xlabel('m/z')
ax0.legend()
ax0.set_ylabel('Frequency')

ax1.set_title('Histogram of Mass values for Pool_49 and Pool_52')
ax1.set_xlabel('m/z')
ax1.legend()
ax1.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
fig, ax = plt.subplots(1, 2, figsize=(15, 5), sharey=True)
ax0, ax1 = ax
for pool in pools:
        # Load the data
        raw_data =pd.read_csv(
                f"../../Data/Datasets/{pool}/Thermo_SRM_{pool}_01_01_3xHCD-1h-R2-tryptic/msmsScans.txt",
                sep='\t', index_col=None)
        ax0.hist(raw_data['Mass'], bins=100, alpha=0.3, label=' '.join(pool.split('_')))
        if pool != 'Pool_60':
                ax1.hist(raw_data['Mass'], bins=100, alpha=0.3, label=' '.join(pool.split('_')))
        print(f"Pool: {pool}, Mean: {raw_data['Mass'].mean()}, Std: {raw_data['Mass'].std()}, Max: {raw_data['Mass'].max()}, Min: {raw_data['Mass'].min()}, Over 3000: {len(raw_data[raw_data['Mass'] > 2900])}")

ax0.set_title('Histogram of Mass values for all pools')
ax0.set_xlabel('Mass')
ax0.legend()
ax0.set_ylabel('Frequency')

ax1.set_title('Histogram of Mass values for Pool_49 and Pool_52')
ax1.set_xlabel('Mass')
ax1.legend()
ax1.set_ylabel('Frequency')
# Out:
# Pool: Pool_49, Mean: 1461.052133114315, Std: 343.1557275782742, Max: 4173.15373293016, Min: 418.221587530098, Over 3000: 264
# Pool: Pool_52, Mean: 1376.1382962600362, Std: 378.11922195894635, Max: 4988.31715627175, Min: 373.207333618679, Over 3000: 228
# Pool: Pool_60, Mean: 1375.52904087135, Std: 441.8398275822941, Max: 3413.37533705759, Min: 462.224944904873, Over 3000: 63
# Text(0, 0.5, 'Frequency')

# %%
# compare the distribution of the mass values
pool_49 = pd.read_csv(
        f"../../Data/Datasets/Pool_49/Thermo_SRM_Pool_49_01_01_3xHCD-1h-R2-tryptic/msmsScans.txt",
        sep='\t', index_col=None)
pool_52 = pd.read_csv(f"../../Data/Datasets/Pool_52/Thermo_SRM_Pool_52_01_01_3xHCD-1h-R2-tryptic/msmsScans.txt",
                      sep='\t', index_col=None)
pool_60 = pd.read_csv(f"../../Data/Datasets/Pool_60/Thermo_SRM_Pool_60_01_01_3xHCD-1h-R2-tryptic/msmsScans.txt",
                      sep='\t', index_col=None)
# convert the mass values to numpy arrays
"""pool_49 = pool_49['Mass'].to_numpy()
pool_52 = pool_52['Mass'].to_numpy()
pool_60 = pool_60['Mass'].to_numpy()"""

"""pool49_52 =  ks_2samp(pool_49, pool_52)
pool49_60 =  ks_2samp(pool_49, pool_60)
pool52_60 =  ks_2samp(pool_52, pool_60)

print(f"KS test for Pool_49 and Pool_52: pvalue: {pool49_52.pvalue}, statistic: {pool49_52.statistic}")
print(f"KS test for Pool_49 and Pool_60: pvalue {pool49_60.pvalue}, statistic: {pool49_60.statistic}")
print(f"KS test for Pool_52 and Pool_60: pvalue {pool52_60.pvalue}, statistic: {pool52_60.statistic}")"""

fig = plt.figure()
pool_49.boxplot(column='Mass', positions=[1])
pool_52.boxplot(column='Mass', positions=[2])
pool_60.boxplot(column='Mass', positions=[3])
plt.title('Boxplot of Mass values')
plt.show()

# random test
random_data = np.random.normal(0, 1, 1000)
random_data2 = np.random.normal(0, 1, 1000)
random_data3 = np.random.normal(0, 1, 1000)
ks_2samp(random_data, random_data2)
# Out:
# KstestResult(statistic=0.052, pvalue=0.13385273551786803, statistic_location=0.726270597848664, statistic_sign=1)

# %%
plot = plt.figure()
for pool in pools:
        # Load the data
        raw_data =pd.read_csv(
                f"../../Data/Datasets/{pool}/Thermo_SRM_{pool}_01_01_3xHCD-1h-R2-tryptic/msmsScans.txt",
                sep='\t', index_col=None)
        plt.hist(raw_data['Length'], alpha=0.3, label=' '.join(pool.split('_')))
plt.xlabel('Length')
plt.ylabel('Frequency')
plt.title('Histogram of Length values')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(1, 3, figsize=(15, 5), sharey=True)
col = 0
for pool in pools:
        # Load the data
        raw_data =pd.read_csv(
                f"../../Data/Datasets/{pool}/Thermo_SRM_{pool}_01_01_3xHCD-1h-R2-tryptic/msmsScans.txt",
                sep='\t', index_col=None)
        print(raw_data.columns)
        direcTag = pd.read_csv(
                f"../../Data/ScoringResults/{pool}/direcTag_scored.tsv",
                sep='\t', index_col=None)
        print(direcTag.columns)
        merged = pd.merge(direcTag, raw_data, left_on='ID', right_on='Scan number', how='inner')
        ax[col].hist(raw_data['Filtered peaks'], bins=100, alpha=0.3, label='raw')
        ax[col].hist(merged['Filtered peaks'], bins=100, alpha=0.3, label='direcTag')
        ax[col].set_title('Histogram of number of \nfiltered peaks for ' + pool)
        ax[col].set_xlabel('Filtered peaks')
        ax[col].legend()
        col+=1

ax[0].set_ylabel('Frequency')
# Out:
# Index(['Raw file', 'Scan number', 'Retention time', 'Ion injection time',
#        'Total ion current', 'Collision energy', 'Summations',
#        'Base peak intensity', 'Elapsed time', 'Identified', 'MS/MS IDs',
#        'Sequence', 'Length', 'Filtered peaks', 'm/z', 'Mass', 'Charge', 'Type',
#        'Fragmentation', 'Mass analyzer', 'Parent intensity fraction',
#        'Fraction of total spectrum', 'Base peak fraction',
#        'Precursor full scan number', 'Precursor intensity',
#        'Precursor apex fraction', 'Precursor apex offset',
#        'Precursor apex offset time', 'Scan event number', 'Modifications',
#        'Modified sequence', 'Proteins', 'Score', 'Experiment',
#        'Intens Comp Factor', 'CTCD Comp', 'RawOvFtT', 'AGC Fill', 'Scan index',
#        'MS scan index', 'MS scan number'],
#       dtype='object')
# Index(['ID', 'Predicted', 'Actual', 'Similarity', 'Identity',
#        'Local Alignment', 'Global Alignment', 'Normalized Local Alignment',
#        'Normalized Global Alignment', 'Levenshtein'],
#       dtype='object')
# Index(['Raw file', 'Scan number', 'Retention time', 'Ion injection time',
#        'Total ion current', 'Collision energy', 'Summations',
#        'Base peak intensity', 'Elapsed time', 'Identified', 'MS/MS IDs',
#        'Sequence', 'Length', 'Filtered peaks', 'm/z', 'Mass', 'Charge', 'Type',
#        'Fragmentation', 'Mass analyzer', 'Parent intensity fraction',
#        'Fraction of total spectrum', 'Base peak fraction',
#        'Precursor full scan number', 'Precursor intensity',
#        'Precursor apex fraction', 'Precursor apex offset',
#        'Precursor apex offset time', 'Scan event number', 'Modifications',
#        'Modified sequence', 'Proteins', 'Score', 'Experiment',
#        'Intens Comp Factor', 'CTCD Comp', 'RawOvFtT', 'AGC Fill', 'Scan index',
#        'MS scan index', 'MS scan number'],
#       dtype='object')
# Index(['ID', 'Predicted', 'Actual', 'Similarity', 'Identity',
#        'Local Alignment', 'Global Alignment', 'Normalized Local Alignment',
#        'Normalized Global Alignment', 'Levenshtein'],
#       dtype='object')
# Index(['Raw file', 'Scan number', 'Retention time', 'Ion injection time',
#        'Total ion current', 'Collision energy', 'Summations',
#        'Base peak intensity', 'Elapsed time', 'Identified', 'MS/MS IDs',
#        'Sequence', 'Length', 'Filtered peaks', 'm/z', 'Mass', 'Charge', 'Type',
#        'Fragmentation', 'Mass analyzer', 'Parent intensity fraction',
#        'Fraction of total spectrum', 'Base peak fraction',
#        'Precursor full scan number', 'Precursor intensity',
#        'Precursor apex fraction', 'Precursor apex offset',
#        'Precursor apex offset time', 'Scan event number', 'Modifications',
#        'Modified sequence', 'Proteins', 'Score', 'Experiment',
#        'Intens Comp Factor', 'CTCD Comp', 'RawOvFtT', 'AGC Fill', 'Scan index',
#        'MS scan index', 'MS scan number'],
#       dtype='object')
# Index(['ID', 'Predicted', 'Actual', 'Similarity', 'Identity',
#        'Local Alignment', 'Global Alignment', 'Normalized Local Alignment',
#        'Normalized Global Alignment', 'Levenshtein'],
#       dtype='object')
# Text(0, 0.5, 'Frequency')
